# %% [markdown]
# ### 1. IMPORT PACKAGES

# %%
#!pip install pandas numpy yfinance matplotlib
#!pip install scikit-learn
#!pip install torch
#!pip install shap
#!pip install optuna

# %%
# Data Preprocessing
import datetime
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# Normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import randint, uniform

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
import optuna

# Others
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Plotting Parameters
plt.rcParams['figure.figsize'] = (16,9)
plt.rcParams['axes.grid'] = True
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# ### 2. DATASET

# %%
# loading sentiment scores
sentiment_scores_df = pd.read_csv('daily-avg-sentiment-scores.csv', index_col=1)
sentiment_scores_df = sentiment_scores_df.iloc[:, 1]
sentiment_scores_df = pd.DataFrame(sentiment_scores_df)
sentiment_scores_df.index = pd.to_datetime(sentiment_scores_df.index)
sentiment_scores_df = sentiment_scores_df[sentiment_scores_df.index >= '2019-07-01']
sentiment_scores_df.head()
# Out:
#             sentiment_score_x
# created_at
# 2019-07-01                NaN
# 2019-07-02                NaN
# 2019-07-03                NaN
# 2019-07-04                NaN
# 2019-07-05                NaN

# %%
# Check for null values
null_values = sentiment_scores_df.isnull().sum()
print(null_values)

# Substitute null values with the mean of the column
sentiment_scores_df.fillna(sentiment_scores_df.mean(), inplace=True)

# Verify that there are no more null values
null_values_after = sentiment_scores_df.isnull().sum()
print(null_values_after)

sentiment_scores_df.head()
# Out:
# sentiment_score_x    152
# dtype: int64
# sentiment_score_x    0
# dtype: int64
#             sentiment_score_x
# created_at
# 2019-07-01           0.084471
# 2019-07-02           0.084471
# 2019-07-03           0.084471
# 2019-07-04           0.084471
# 2019-07-05           0.084471

# %%
# Set the start and end dates
start_time_all = datetime.datetime(2019, 7, 1) # 2020-01-01
end_time_train = datetime.datetime(2020, 9, 8) # 2020-06-30
end_time_all = datetime.datetime(2020, 12, 2) # 2020-12-31

# Download TSLA data
tsla_price_df = yf.download('TSLA', start=start_time_all, end=end_time_all)
tsla_price_df.index = pd.to_datetime(tsla_price_df.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tsla_price_df.head()
# Out:
# Price                      Adj Close      Close       High        Low  \
# Ticker                          TSLA       TSLA       TSLA       TSLA
# Date
# 2019-07-01 00:00:00+00:00  15.144667  15.144667  15.540000  15.085333
# 2019-07-02 00:00:00+00:00  14.970000  14.970000  15.276667  14.814667
# 2019-07-03 00:00:00+00:00  15.660000  15.660000  16.104668  15.634000
# 2019-07-05 00:00:00+00:00  15.540000  15.540000  15.696667  15.386667
# 2019-07-08 00:00:00+00:00  15.356000  15.356000  15.483333  15.244000
#
# Price                           Open     Volume
# Ticker                          TSLA       TSLA
# Date
# 2019-07-01 00:00:00+00:00  15.347333  123201000
# 2019-07-02 00:00:00+00:00  15.259333  138885000
# 2019-07-03 00:00:00+00:00  15.959333  213016500
# 2019-07-05 00:00:00+00:00  15.638000  105985500
# 2019-07-08 00:00:00+00:00  15.416000   88207500

# %%
tsla_price_df.tail()
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           TSLA        TSLA        TSLA        TSLA
# Date
# 2020-11-24 00:00:00+00:00  185.126663  185.126663  186.663330  175.399994
# 2020-11-25 00:00:00+00:00  191.333328  191.333328  191.333328  181.789993
# 2020-11-27 00:00:00+00:00  195.253326  195.253326  199.593338  192.816666
# 2020-11-30 00:00:00+00:00  189.199997  189.199997  202.600006  184.836670
# 2020-12-01 00:00:00+00:00  194.919998  194.919998  199.283340  190.683334
#
# Price                            Open     Volume
# Ticker                           TSLA       TSLA
# Date
# 2020-11-24 00:00:00+00:00  180.133331  160945500
# 2020-11-25 00:00:00+00:00  183.353333  146790600
# 2020-11-27 00:00:00+00:00  193.720001  112683300
# 2020-11-30 00:00:00+00:00  200.736664  189009300
# 2020-12-01 00:00:00+00:00  199.196671  120310500

# %%
# Adding the daily return
tsla_price_df['Return'] = tsla_price_df['Adj Close'].pct_change()
print(tsla_price_df)
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           TSLA        TSLA        TSLA        TSLA
# Date
# 2019-07-01 00:00:00+00:00   15.144667   15.144667   15.540000   15.085333
# 2019-07-02 00:00:00+00:00   14.970000   14.970000   15.276667   14.814667
# 2019-07-03 00:00:00+00:00   15.660000   15.660000   16.104668   15.634000
# 2019-07-05 00:00:00+00:00   15.540000   15.540000   15.696667   15.386667
# 2019-07-08 00:00:00+00:00   15.356000   15.356000   15.483333   15.244000
# ...                               ...         ...         ...         ...
# 2020-11-24 00:00:00+00:00  185.126663  185.126663  186.663330  175.399994
# 2020-11-25 00:00:00+00:00  191.333328  191.333328  191.333328  181.789993
# 2020-11-27 00:00:00+00:00  195.253326  195.253326  199.593338  192.816666
# 2020-11-30 00:00:00+00:00  189.199997  189.199997  202.600006  184.836670
# 2020-12-01 00:00:00+00:00  194.919998  194.919998  199.283340  190.683334
#
# Price                            Open     Volume    Return
# Ticker                           TSLA       TSLA
# Date
# 2019-07-01 00:00:00+00:00   15.347333  123201000       NaN
# 2019-07-02 00:00:00+00:00   15.259333  138885000 -0.011533
# 2019-07-03 00:00:00+00:00   15.959333  213016500  0.046092
# 2019-07-05 00:00:00+00:00   15.638000  105985500 -0.007663
# 2019-07-08 00:00:00+00:00   15.416000   88207500 -0.011840
# ...                               ...        ...       ...
# 2020-11-24 00:00:00+00:00  180.133331  160945500  0.064252
# 2020-11-25 00:00:00+00:00  183.353333  146790600  0.033527
# 2020-11-27 00:00:00+00:00  193.720001  112683300  0.020488
# 2020-11-30 00:00:00+00:00  200.736664  189009300 -0.031002
# 2020-12-01 00:00:00+00:00  199.196671  120310500  0.030233
#
# [360 rows x 7 columns]

# %%
# Adding the sentiment scores
# Restablecer el índice de columnas si tiene niveles adicionales
tsla_price_df.columns = tsla_price_df.columns.get_level_values(-2)

print(tsla_price_df)
print(sentiment_scores_df)

# Asegúrate de que ambos índices sean tz-naive
tsla_price_df.index = tsla_price_df.index.tz_localize(None)
sentiment_scores_df.index = sentiment_scores_df.index.tz_localize(None)

# Realiza el merge
tsla_price_df = pd.merge(tsla_price_df, sentiment_scores_df, left_index=True, right_index=True)
tsla_price_df = tsla_price_df.rename(columns={'sentiment_score_x': 'Sentiment Score'})
# Out:
# Price                       Adj Close       Close        High         Low  \
# Date
# 2019-07-01 00:00:00+00:00   15.144667   15.144667   15.540000   15.085333
# 2019-07-02 00:00:00+00:00   14.970000   14.970000   15.276667   14.814667
# 2019-07-03 00:00:00+00:00   15.660000   15.660000   16.104668   15.634000
# 2019-07-05 00:00:00+00:00   15.540000   15.540000   15.696667   15.386667
# 2019-07-08 00:00:00+00:00   15.356000   15.356000   15.483333   15.244000
# ...                               ...         ...         ...         ...
# 2020-11-24 00:00:00+00:00  185.126663  185.126663  186.663330  175.399994
# 2020-11-25 00:00:00+00:00  191.333328  191.333328  191.333328  181.789993
# 2020-11-27 00:00:00+00:00  195.253326  195.253326  199.593338  192.816666
# 2020-11-30 00:00:00+00:00  189.199997  189.199997  202.600006  184.836670
# 2020-12-01 00:00:00+00:00  194.919998  194.919998  199.283340  190.683334
#
# Price                            Open     Volume    Return
# Date
# 2019-07-01 00:00:00+00:00   15.347333  123201000       NaN
# 2019-07-02 00:00:00+00:00   15.259333  138885000 -0.011533
# 2019-07-03 00:00:00+00:00   15.959333  213016500  0.046092
# 2019-07-05 00:00:00+00:00   15.638000  105985500 -0.007663
# 2019-07-08 00:00:00+00:00   15.416000   88207500 -0.011840
# ...                               ...        ...       ...
# 2020-11-24 00:00:00+00:00  180.133331  160945500  0.064252
# 2020-11-25 00:00:00+00:00  183.353333  146790600  0.033527
# 2020-11-27 00:00:00+00:00  193.720001  112683300  0.020488
# 2020-11-30 00:00:00+00:00  200.736664  189009300 -0.031002
# 2020-12-01 00:00:00+00:00  199.196671  120310500  0.030233
#
# [360 rows x 7 columns]
#             sentiment_score_x
# created_at
# 2019-07-01           0.084471
# 2019-07-02           0.084471
# 2019-07-03           0.084471
# 2019-07-04           0.084471
# 2019-07-05           0.084471
# ...                       ...
# 2020-11-27           0.068470
# 2020-11-28           0.075972
# 2020-11-29           0.071454
# 2020-11-30           0.087666
# 2020-12-01           0.072367
#
# [520 rows x 1 columns]

# %%
tsla_price_df.head()
# Out:
#             Adj Close      Close       High        Low       Open     Volume  \
# 2019-07-01  15.144667  15.144667  15.540000  15.085333  15.347333  123201000
# 2019-07-02  14.970000  14.970000  15.276667  14.814667  15.259333  138885000
# 2019-07-03  15.660000  15.660000  16.104668  15.634000  15.959333  213016500
# 2019-07-05  15.540000  15.540000  15.696667  15.386667  15.638000  105985500
# 2019-07-08  15.356000  15.356000  15.483333  15.244000  15.416000   88207500
#
#               Return  Sentiment Score
# 2019-07-01       NaN         0.084471
# 2019-07-02 -0.011533         0.084471
# 2019-07-03  0.046092         0.084471
# 2019-07-05 -0.007663         0.084471
# 2019-07-08 -0.011840         0.084471

# %%
# plotting TSLA Adj Close price from 2020-01-01 to 2020-12-31
plt.plot(tsla_price_df.index, tsla_price_df['Adj Close'])
plt.xlabel('Date')
plt.ylabel('Adj Close Price')
plt.xlim(start_time_all, end_time_all)
plt.title('TSLA Adj Close Price')
plt.show()

# %% [markdown]
# ### 2.5 DATA ANALYSIS

# %% [markdown]
# #### High

# %%
# Calculating correlation between 'Adj Close' and 'High'
correlation = tsla_price_df['Adj Close'].corr(tsla_price_df['High'])
print("Correlation between 'Adj Close' and 'High':", correlation)
# Out:
# Correlation between 'Adj Close' and 'High': 0.9991978749400866

# %%
sns.regplot(x=tsla_price_df['Adj Close'][1:], y=tsla_price_df['High'][1:])
plt.title('Correlation Adj Return and High')
plt.show()

# %% [markdown]
# #### Low

# %%
# Calculating correlation between 'Adj Close' and 'Low'
correlation = tsla_price_df['Adj Close'].corr(tsla_price_df['Low'])
print("Correlation between 'Adj Close' and 'Low':", correlation)
# Out:
# Correlation between 'Adj Close' and 'Low': 0.998899125855901

# %%
sns.regplot(x=tsla_price_df['Adj Close'][1:], y=tsla_price_df['Low'][1:])
plt.title('Correlation Adj Return and Low')
plt.show()

# %% [markdown]
# #### Volume

# %%
# Calculating correlation between 'Adj Close' and 'Volume'
correlation = tsla_price_df['Adj Close'].corr(tsla_price_df['Volume'])
print("Correlation between 'Adj Close' and 'Volume':", correlation)
# Out:
# Correlation between 'Adj Close' and 'Volume': 0.07077477932264548

# %%
sns.regplot(x=tsla_price_df['Adj Close'][1:], y=tsla_price_df['Volume'][1:])
plt.title('Correlation Adj Return and Volume')
plt.show()

# %% [markdown]
# #### Sentiment Score

# %%
# Calculating correlation between 'Adj Close' and 'Sentiment Score'
correlation = tsla_price_df['Adj Close'].corr(tsla_price_df['Sentiment Score'])
print("Correlation between 'Adj Close' and 'Sentiment Score':", correlation)
# Out:
# Correlation between 'Adj Close' and 'Sentiment Score': 0.1832114187301956

# %%
sns.regplot(x=tsla_price_df['Adj Close'][1:], y=tsla_price_df['Sentiment Score'][1:])
plt.title('Correlation Adj Return and Sentiment Score')
plt.show()

# %%
sns.jointplot(x='Adj Close', y='Sentiment Score', data=tsla_price_df[1:], kind='kde', fill=True)
plt.suptitle('Jointplot of Daily Returns and Sentiment Scores')
plt.show()

# %%
# Calculating correlation between 'Adj Close' and 'Sentiment Score'
correlation = tsla_price_df['Return'].corr(tsla_price_df['Sentiment Score'])
print("Correlation between 'Return' and 'Sentiment Score':", correlation)
# Out:
# Correlation between 'Return' and 'Sentiment Score': 0.06071165005524115

# %%
sns.regplot(x=tsla_price_df['Return'][1:], y=tsla_price_df['Sentiment Score'][1:], color='g')
plt.title('Correlation between Daily Returns and Sentiment Scores')
plt.show()

# %%
# Features variables (Close price, High price, Low price, Open price, Volume)
X = tsla_price_df.drop(['Adj Close'], axis=1)

# Traget variable (Adj Close price)
y = tsla_price_df.iloc[:, 0:1]

# %% [markdown]
# ### 3. NORMALIZATION OF DATA

# %%
# Split the dataset into training and testing sets (80% training, 20% testing)
train_df, test_df = train_test_split(tsla_price_df, test_size=0.2, shuffle=False)

# Normalize the features (Close, High, Low, Open, Volume)
features = ['Close', 'High', 'Low', 'Open', 'Volume', 'Sentiment Score']
scaler_features = MinMaxScaler()
train_features = scaler_features.fit_transform(train_df[features])
test_features = scaler_features.transform(test_df[features])

# Create a new DataFrame with the normalized features
train_features_df = pd.DataFrame(train_features, columns=features, index=train_df.index)
test_features_df = pd.DataFrame(test_features, columns=features, index=test_df.index)

# Normalize the target column ('Adj Close') separately
scaler_target = MinMaxScaler(feature_range=(0, 1))
train_target = scaler_target.fit_transform(train_df[['Adj Close']].values)
test_target = scaler_target.transform(test_df[['Adj Close']].values)

# Create a new DataFrame with the normalized target
train_target_df = pd.DataFrame(train_target, columns=['Adj Close'], index=train_df.index)
test_target_df = pd.DataFrame(test_target, columns=['Adj Close'], index=test_df.index)

# Combine the features and target DataFrames
train_data = pd.concat([train_features_df, train_target_df], axis=1)
test_data = pd.concat([test_features_df, test_target_df], axis=1)

train_data, val_data = train_test_split(train_data, test_size=0.15, shuffle=False)

# Print the first records of normalized data and the dimensions of the tensors
print("First records of normalized data (features):")
print(train_features_df.head())

print("\nFirst records of normalized data (target):")
print(train_target[:5])
# Out:
# First records of normalized data (features):
#                Close      High       Low      Open    Volume  Sentiment Score
# 2019-07-01  0.009411  0.010580  0.009351  0.009855  0.098298         0.567771
# 2019-07-02  0.007848  0.008269  0.006866  0.009072  0.116180         0.567771
# 2019-07-03  0.014024  0.015536  0.014387  0.015302  0.200699         0.567771
# 2019-07-05  0.012950  0.011955  0.012117  0.012442  0.078670         0.567771
# 2019-07-08  0.011303  0.010083  0.010807  0.010466  0.058401         0.567771
#
# First records of normalized data (target):
# [[0.00941105]
#  [0.00784752]
#  [0.01402407]
#  [0.01294989]
#  [0.01130281]]

# %%
plt.figure(figsize=(12, 6))
plt.plot(tsla_price_df.index, scaler_target.transform(tsla_price_df[['Adj Close']]), label='Adj Close')
plt.xlabel('Date')
plt.ylabel('Normalized Adj Close Price')
plt.xlim(start_time_all, end_time_all)
plt.title('Normalized TSLA Adj Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ### 4. LSTM MODEL DEFINITION

# %%
def create_sequences(data, seq_length):
    xs = []
    ys = []
    for i in range(len(data) - seq_length):
        x = data[i:(i + seq_length), :-1] 
        y = data[i + seq_length, -1]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 15
train_array = train_data.values
val_array = val_data.values

X_train, y_train = create_sequences(train_array, seq_length)
X_val, y_val = create_sequences(val_array, seq_length)

import torch
from torch.utils.data import TensorDataset, DataLoader

# Convert the data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

# Create a DataLoader
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128)

# %%
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
# Plot the training and validation losses
def plot_losses(train_losses_over_epochs, val_losses_over_epochs, num_epochs):
    plt.figure()
    plt.plot(range(1, num_epochs+1), train_losses_over_epochs, label='Training Loss', color='blue')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Loss per Epoch')
    plt.legend()
    plt.show()

    plt.figure()
    plt.plot(range(1, num_epochs+1), val_losses_over_epochs, label='Validation Loss', color='orange')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Validation Loss per Epoch')
    plt.legend()
    plt.show()

# %%
# Adaptation of the plotting function for predictions
def plt_graph(start_time, end_time, period, y_test_rescaled, y_pred_rescaled, val_line=False):
    plt.figure(figsize=(12, 6))
    plt.plot(test_data.index[seq_length:], y_test_rescaled, label='Actual Price')
    plt.plot(test_data.index[seq_length:], y_pred_rescaled, label='Predicted Price')
    
    if val_line:
        plt.axvline(x=end_time_train, c='r', linestyle='--')
    
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.xlim(start_time, end_time)
    plt.title(f'{period} Period')
    plt.legend()
    plt.show()

# %% [markdown]
# ### 5. LSTM MODEL 1.0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Basic Hyperparameters
input_size = X_train.shape[2]
hidden_size = 50
num_layers = 2
dropout_prob = 0.2

# Initialize the LSTM model
model = LSTMModel(input_size, hidden_size, num_layers, dropout_prob).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 75

train_losses_over_epochs = []
val_losses_over_epochs = []

# Train the model
for epoch in range(num_epochs):
    model.train()
    train_losses = []
    
    # Training loss
    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs.squeeze(), y_batch)
        loss.backward()
        
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        train_losses.append(loss.item())
    
    avg_train_loss = sum(train_losses) / len(train_losses)
    train_losses_over_epochs.append(avg_train_loss)
    
    # Validation loss
    model.eval()
    val_losses = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            outputs = model(X_batch)
            val_loss = criterion(outputs.squeeze(), y_batch)
            val_losses.append(val_loss.item())
            
    avg_val_loss = sum(val_losses) / len(val_losses)
    val_losses_over_epochs.append(avg_val_loss)
    
    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

# Plot the training and validation losses
plot_losses(train_losses_over_epochs, val_losses_over_epochs, num_epochs)
# Out:
# Epoch 5/75, Loss: 0.0329, Val Loss: 0.4608
# Epoch 10/75, Loss: 0.0202, Val Loss: 0.2079
# Epoch 15/75, Loss: 0.0134, Val Loss: 0.2691
# Epoch 20/75, Loss: 0.0069, Val Loss: 0.0624
# Epoch 25/75, Loss: 0.0025, Val Loss: 0.0124
# Epoch 30/75, Loss: 0.0019, Val Loss: 0.0251
# Epoch 35/75, Loss: 0.0016, Val Loss: 0.0111
# Epoch 40/75, Loss: 0.0017, Val Loss: 0.0080
# Epoch 45/75, Loss: 0.0015, Val Loss: 0.0081
# Epoch 50/75, Loss: 0.0016, Val Loss: 0.0081
# Epoch 55/75, Loss: 0.0014, Val Loss: 0.0074
# Epoch 60/75, Loss: 0.0013, Val Loss: 0.0074
# Epoch 65/75, Loss: 0.0014, Val Loss: 0.0068
# Epoch 70/75, Loss: 0.0012, Val Loss: 0.0064
# Epoch 75/75, Loss: 0.0012, Val Loss: 0.0063

# %%
# Set the model to evaluation mode
test_array = test_data.values
X_test, y_test = create_sequences(test_array, seq_length)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

model.eval()
with torch.no_grad():
    predictions = model(X_test_tensor)

# Rescale the predicted and actual values
predictions = predictions.numpy()
y_test = y_test_tensor.numpy()
y_pred_rescaled = scaler_target.inverse_transform(predictions)
y_test_rescaled = scaler_target.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test RMSE: {rmse:.4f}")

# Plotting function for predictions
plt_graph(start_time=end_time_train, end_time=end_time_all, period='Test', y_test_rescaled=y_test_rescaled, y_pred_rescaled=y_pred_rescaled, val_line=True)
# Out:
# Test MSE: 314.6341
# Test MAE: 12.6178
# Test RMSE: 17.7379

# %% [markdown]
# ### 6. HYPERPARAMETERS TUNNING

# %%
def objective(trial):
    # Define the hyperparameters to optimize
    hidden_size = trial.suggest_int('hidden_size', 32, 128)
    num_layers = trial.suggest_int('num_layers', 1, 3)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    dropout_prob = trial.suggest_float('dropout_prob', 0.1, 0.5)

    # Define the model, loss function, and optimizer
    input_size = X_train.shape[2]
    model = LSTMModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, dropout=dropout_prob).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # Train the model
    num_epochs = 50

    for epoch in range(num_epochs):
        model.train()
        train_losses = []
        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs.squeeze(), y_batch)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_losses.append(loss.item())

    # Evaluate the model on the validation set
    model.eval()
    val_losses = []
    preds_list = []
    y_val_list = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = model(X_batch)
            val_loss = criterion(outputs.squeeze(), y_batch)
            val_losses.append(val_loss.item())
            preds_list.extend(outputs.squeeze().cpu().numpy())
            y_val_list.extend(y_batch.cpu().numpy())

    avg_val_loss = np.mean(val_losses)

    # Rescale the predicted and actual values
    y_pred_rescaled = scaler_target.inverse_transform(np.array(preds_list).reshape(-1, 1))
    y_val_rescaled = scaler_target.inverse_transform(np.array(y_val_list).reshape(-1, 1))

    # Calculate metrics
    mse = mean_squared_error(y_val_rescaled, y_pred_rescaled)
    mae = mean_absolute_error(y_val_rescaled, y_pred_rescaled)
    rmse = np.sqrt(mse)
    trial.set_user_attr('val_mae', mae)
    trial.set_user_attr('val_rmse', rmse)

    return avg_val_loss

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
best_params = study.best_params
best_trial = study.best_trial

# Print the best parameters and metrics
print("\nBest parameters:")
print(best_params)
print(f"Best MSE: {study.best_value}")
print(f"Best MAE: {best_trial.user_attrs['val_mae']}")
print(f"Best RMSE: {best_trial.user_attrs['val_rmse']}")
# Out:
# [I 2024-11-09 20:53:59,254] A new study created in memory with name: no-name-ac7d4140-1cf3-4dde-8f38-899d2fa054bd
# [I 2024-11-09 20:54:01,810] Trial 0 finished with value: 0.003463881555944681 and parameters: {'hidden_size': 128, 'num_layers': 1, 'learning_rate': 0.00833047160618496, 'dropout_prob': 0.10567717494107627}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:04,188] Trial 1 finished with value: 0.0377073809504509 and parameters: {'hidden_size': 49, 'num_layers': 3, 'learning_rate': 0.0005109109655130205, 'dropout_prob': 0.181659923882174}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:05,981] Trial 2 finished with value: 0.0294446162879467 and parameters: {'hidden_size': 34, 'num_layers': 3, 'learning_rate': 0.0003036193075407705, 'dropout_prob': 0.2233193459854113}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:08,121] Trial 3 finished with value: 0.059078723192214966 and parameters: {'hidden_size': 55, 'num_layers': 2, 'learning_rate': 0.00019053545317224252, 'dropout_prob': 0.37528615206176485}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:10,478] Trial 4 finished with value: 0.008430003188550472 and parameters: {'hidden_size': 62, 'num_layers': 2, 'learning_rate': 0.0021762752999263065, 'dropout_prob': 0.21300409590363434}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:12,186] Trial 5 finished with value: 0.008138691075146198 and parameters: {'hidden_size': 93, 'num_layers': 1, 'learning_rate': 0.0011808786257043033, 'dropout_prob': 0.3282691328784635}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:13,167] Trial 6 finished with value: 0.35263991355895996 and parameters: {'hidden_size': 56, 'num_layers': 1, 'learning_rate': 0.00010671151159031006, 'dropout_prob': 0.38246046764522845}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:14,723] Trial 7 finished with value: 0.011359571479260921 and parameters: {'hidden_size': 48, 'num_layers': 2, 'learning_rate': 0.0003903872913975663, 'dropout_prob': 0.22360166585584415}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:17,866] Trial 8 finished with value: 0.027694877237081528 and parameters: {'hidden_size': 64, 'num_layers': 3, 'learning_rate': 0.0009452299114636652, 'dropout_prob': 0.23970313797613776}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:19,294] Trial 9 finished with value: 0.004383289720863104 and parameters: {'hidden_size': 82, 'num_layers': 1, 'learning_rate': 0.0017922915968583118, 'dropout_prob': 0.47202950258221965}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:21,693] Trial 10 finished with value: 0.0035002902150154114 and parameters: {'hidden_size': 128, 'num_layers': 1, 'learning_rate': 0.008741694629854557, 'dropout_prob': 0.10572486123664272}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:24,003] Trial 11 finished with value: 0.0037366067990660667 and parameters: {'hidden_size': 128, 'num_layers': 1, 'learning_rate': 0.009652804299076369, 'dropout_prob': 0.1013017617234794}. Best is trial 0 with value: 0.003463881555944681.
# [I 2024-11-09 20:54:26,094] Trial 12 finished with value: 0.0025669713504612446 and parameters: {'hidden_size': 128, 'num_layers': 1, 'learning_rate': 0.008435007161505265, 'dropout_prob': 0.10249569396479655}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:28,033] Trial 13 finished with value: 0.0035416376776993275 and parameters: {'hidden_size': 110, 'num_layers': 1, 'learning_rate': 0.0038415802737710855, 'dropout_prob': 0.154869782709094}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:32,187] Trial 14 finished with value: 0.009311863221228123 and parameters: {'hidden_size': 111, 'num_layers': 2, 'learning_rate': 0.004176503712961946, 'dropout_prob': 0.16084378346048303}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:34,531] Trial 15 finished with value: 0.0036703760270029306 and parameters: {'hidden_size': 111, 'num_layers': 1, 'learning_rate': 0.0045763936124481805, 'dropout_prob': 0.2770504742132254}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:38,250] Trial 16 finished with value: 0.012286294251680374 and parameters: {'hidden_size': 98, 'num_layers': 2, 'learning_rate': 0.006201861976904394, 'dropout_prob': 0.1369222457665404}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:40,451] Trial 17 finished with value: 0.0035926622804254293 and parameters: {'hidden_size': 119, 'num_layers': 1, 'learning_rate': 0.002054944202441979, 'dropout_prob': 0.3087300738864117}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:44,291] Trial 18 finished with value: 0.0070919496938586235 and parameters: {'hidden_size': 99, 'num_layers': 2, 'learning_rate': 0.0029604370775753513, 'dropout_prob': 0.12443206116585329}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:45,581] Trial 19 finished with value: 0.0028962125070393085 and parameters: {'hidden_size': 80, 'num_layers': 1, 'learning_rate': 0.006162225314429754, 'dropout_prob': 0.4856502686323808}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:46,921] Trial 20 finished with value: 0.02262708730995655 and parameters: {'hidden_size': 76, 'num_layers': 1, 'learning_rate': 0.0009149312620918289, 'dropout_prob': 0.4897740947594493}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:49,095] Trial 21 finished with value: 0.002678835531696677 and parameters: {'hidden_size': 120, 'num_layers': 1, 'learning_rate': 0.006244657322729431, 'dropout_prob': 0.4400365737121369}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:50,524] Trial 22 finished with value: 0.0029209316708147526 and parameters: {'hidden_size': 82, 'num_layers': 1, 'learning_rate': 0.005853413572766883, 'dropout_prob': 0.4305333220669657}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:52,807] Trial 23 finished with value: 0.0031567781697958708 and parameters: {'hidden_size': 118, 'num_layers': 1, 'learning_rate': 0.006037329964789897, 'dropout_prob': 0.4507591823377695}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:54,177] Trial 24 finished with value: 0.003649812424555421 and parameters: {'hidden_size': 74, 'num_layers': 1, 'learning_rate': 0.0032118415753110197, 'dropout_prob': 0.40712874160360935}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:57,845] Trial 25 finished with value: 0.01921117678284645 and parameters: {'hidden_size': 94, 'num_layers': 2, 'learning_rate': 0.0064111496605580125, 'dropout_prob': 0.4927156992431246}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:54:59,421] Trial 26 finished with value: 0.0027823741547763348 and parameters: {'hidden_size': 88, 'num_layers': 1, 'learning_rate': 0.0031383592930721515, 'dropout_prob': 0.3558632434575705}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:01,692] Trial 27 finished with value: 0.008310424163937569 and parameters: {'hidden_size': 118, 'num_layers': 1, 'learning_rate': 0.001432464962327403, 'dropout_prob': 0.3341763409896274}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:05,731] Trial 28 finished with value: 0.009400825947523117 and parameters: {'hidden_size': 102, 'num_layers': 2, 'learning_rate': 0.0027537618522838086, 'dropout_prob': 0.3571300176444535}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:08,015] Trial 29 finished with value: 0.0052366540767252445 and parameters: {'hidden_size': 121, 'num_layers': 1, 'learning_rate': 0.009883534863435614, 'dropout_prob': 0.2718704449929286}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:09,851] Trial 30 finished with value: 0.002985345898196101 and parameters: {'hidden_size': 88, 'num_layers': 1, 'learning_rate': 0.004573937097762652, 'dropout_prob': 0.4102429336489715}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:11,839] Trial 31 finished with value: 0.004026861395686865 and parameters: {'hidden_size': 104, 'num_layers': 1, 'learning_rate': 0.007400700576987515, 'dropout_prob': 0.45401934412743156}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:13,170] Trial 32 finished with value: 0.002873482648283243 and parameters: {'hidden_size': 72, 'num_layers': 1, 'learning_rate': 0.005055588370811247, 'dropout_prob': 0.42502048803510356}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:14,385] Trial 33 finished with value: 0.0033551501110196114 and parameters: {'hidden_size': 72, 'num_layers': 1, 'learning_rate': 0.004498881832129376, 'dropout_prob': 0.40134718367859223}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:22,154] Trial 34 finished with value: 0.020740315318107605 and parameters: {'hidden_size': 123, 'num_layers': 3, 'learning_rate': 0.003241639962464736, 'dropout_prob': 0.35884485065331756}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:23,459] Trial 35 finished with value: 0.0031387058552354574 and parameters: {'hidden_size': 69, 'num_layers': 1, 'learning_rate': 0.0074164821776873825, 'dropout_prob': 0.44588292528755225}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:24,248] Trial 36 finished with value: 0.007065430283546448 and parameters: {'hidden_size': 43, 'num_layers': 1, 'learning_rate': 0.0006578929578400093, 'dropout_prob': 0.42544502043696486}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:24,959] Trial 37 finished with value: 0.007025222759693861 and parameters: {'hidden_size': 34, 'num_layers': 1, 'learning_rate': 0.0022553496777364132, 'dropout_prob': 0.3798135516729272}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:28,369] Trial 38 finished with value: 0.0074960021302104 and parameters: {'hidden_size': 89, 'num_layers': 2, 'learning_rate': 0.0037328662995936763, 'dropout_prob': 0.19045808976667306}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:31,453] Trial 39 finished with value: 0.0393192283809185 and parameters: {'hidden_size': 60, 'num_layers': 3, 'learning_rate': 0.005087900958471804, 'dropout_prob': 0.334767034697109}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:33,551] Trial 40 finished with value: 0.003747425740584731 and parameters: {'hidden_size': 114, 'num_layers': 1, 'learning_rate': 0.0016214171769886338, 'dropout_prob': 0.3549557025799019}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:34,747] Trial 41 finished with value: 0.002796779153868556 and parameters: {'hidden_size': 65, 'num_layers': 1, 'learning_rate': 0.007611301891861951, 'dropout_prob': 0.47895234186549285}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:35,978] Trial 42 finished with value: 0.0035301961470395327 and parameters: {'hidden_size': 68, 'num_layers': 1, 'learning_rate': 0.007857639189854446, 'dropout_prob': 0.4659902159468775}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:37,126] Trial 43 finished with value: 0.004593810997903347 and parameters: {'hidden_size': 55, 'num_layers': 1, 'learning_rate': 0.008547440657643774, 'dropout_prob': 0.4238264387474768}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:38,255] Trial 44 finished with value: 0.004263154696673155 and parameters: {'hidden_size': 64, 'num_layers': 1, 'learning_rate': 0.0025604558876186497, 'dropout_prob': 0.4686071904596415}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:39,368] Trial 45 finished with value: 0.14405840635299683 and parameters: {'hidden_size': 50, 'num_layers': 1, 'learning_rate': 0.0002645524476786034, 'dropout_prob': 0.40120801994035754}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:44,457] Trial 46 finished with value: 0.00896338652819395 and parameters: {'hidden_size': 124, 'num_layers': 2, 'learning_rate': 0.005278939253431986, 'dropout_prob': 0.26068684507036827}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:46,084] Trial 47 finished with value: 0.0039436393417418 and parameters: {'hidden_size': 86, 'num_layers': 1, 'learning_rate': 0.007411840208549157, 'dropout_prob': 0.3033566184773089}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:47,141] Trial 48 finished with value: 0.0034647216089069843 and parameters: {'hidden_size': 59, 'num_layers': 1, 'learning_rate': 0.0033817083423271325, 'dropout_prob': 0.43788962785018526}. Best is trial 12 with value: 0.0025669713504612446.
# [I 2024-11-09 20:55:49,016] Trial 49 finished with value: 0.0036581181921064854 and parameters: {'hidden_size': 106, 'num_layers': 1, 'learning_rate': 0.009480697950708545, 'dropout_prob': 0.4992683284647902}. Best is trial 12 with value: 0.0025669713504612446.
# Best parameters:
# {'hidden_size': 128, 'num_layers': 1, 'learning_rate': 0.008435007161505265, 'dropout_prob': 0.10249569396479655}
# Best MSE: 0.0025669713504612446
# Best MAE: 4.024212837219238
# Best RMSE: 5.659953594207764

# %% [markdown]
# ### 7. LSTM MODEL 2.0

# %%
# Set the best hyperparameters
best_hidden_size = best_params['hidden_size']
best_num_layers = best_params['num_layers']
best_learning_rate = best_params['learning_rate']
best_dropout_prob = best_params['dropout_prob']
input_size = X_train.shape[2]

# Initialize the LSTM model with the best hyperparameters
model = LSTMModel(
    input_size=input_size,
    hidden_size=best_hidden_size,
    num_layers=best_num_layers,
    dropout=best_dropout_prob
).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 50

train_losses_over_epochs = []
val_losses_over_epochs = []

# Train the model
for epoch in range(num_epochs):
    model.train()
    train_losses = []
    
    # Training loss
    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs.squeeze(), y_batch)
        loss.backward()
        
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.001)
        
        optimizer.step()
        train_losses.append(loss.item())
    
    avg_train_loss = sum(train_losses) / len(train_losses)
    train_losses_over_epochs.append(avg_train_loss)
    
    # Validation loss
    model.eval()
    val_losses = []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            outputs = model(X_batch)
            val_loss = criterion(outputs.squeeze(), y_batch)
            val_losses.append(val_loss.item())
            
    avg_val_loss = sum(val_losses) / len(val_losses)
    val_losses_over_epochs.append(avg_val_loss)
    
    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

# Save the model
torch.save(model.state_dict(), 'lstm_model_2.0.pth')

plot_losses(train_losses_over_epochs, val_losses_over_epochs, num_epochs)
# Out:
# Epoch 5/50, Loss: 0.0147, Val Loss: 0.1776
# Epoch 10/50, Loss: 0.0026, Val Loss: 0.0066
# Epoch 15/50, Loss: 0.0035, Val Loss: 0.0305
# Epoch 20/50, Loss: 0.0014, Val Loss: 0.0066
# Epoch 25/50, Loss: 0.0010, Val Loss: 0.0131
# Epoch 30/50, Loss: 0.0009, Val Loss: 0.0051
# Epoch 35/50, Loss: 0.0008, Val Loss: 0.0042
# Epoch 40/50, Loss: 0.0007, Val Loss: 0.0039
# Epoch 45/50, Loss: 0.0007, Val Loss: 0.0036
# Epoch 50/50, Loss: 0.0007, Val Loss: 0.0033

# %%
# Set the model to evaluation mode
test_array = test_data.values
X_test, y_test = create_sequences(test_array, seq_length)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

model.eval()
with torch.no_grad():
    predictions = model(X_test_tensor)

# Rescale the predicted and actual values
predictions = predictions.numpy()
y_test = y_test_tensor.numpy()
y_pred_rescaled = scaler_target.inverse_transform(predictions)
y_test_rescaled = scaler_target.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test RMSE: {rmse:.4f}")

# Plotting function for predictions
plt_graph(start_time=end_time_train, end_time=end_time_all, period='Test', y_test_rescaled=y_test_rescaled, y_pred_rescaled=y_pred_rescaled, val_line=True)
# Out:
# Test MSE: 82.0883
# Test MAE: 7.1163
# Test RMSE: 9.0603
